# %%
import nltk
import pandas as pd
import numpy as np
import altair as alt

# %%
annotation_df = pd.read_csv("../Milestone_3/Monica_Chandler_Annotated.csv")
annotation_df
# Out:
#                                        episode  \
# 0     Episode 101: The Pilot-The Uncut Version
# 1     Episode 101: The Pilot-The Uncut Version
# 2     Episode 101: The Pilot-The Uncut Version
# 3     Episode 101: The Pilot-The Uncut Version
# 4     Episode 101: The Pilot-The Uncut Version
# ...                                        ...
# 1143            Episode 1018: The Last One (2)
# 1144            Episode 1018: The Last One (2)
# 1145            Episode 1018: The Last One (2)
# 1146            Episode 1018: The Last One (2)
# 1147            Episode 1018: The Last One (2)
#
#                                                   scene  \
# 0      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 1      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 2      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 3      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 4      Central Perk, Chandler, Joey, Phoebe, and Mon...
# ...                                                 ...
# 1143   Joey's apartment. Joey and Chandler are still...
# 1144   Joey's apartment. Monica has completely destr...
# 1145   Monica and Chandler's apartment. Joey, Chandl...
# 1146   Monica and Chandler's apartment. Chandler and...
# 1147   Monica and Chandler's apartment. Chandler and...
#
#                                                   texts  C1  C2
# 0     [['Monica', "Okay, everybody relax. This is no...   0   0
# 1     [['Chandler', "All of a sudden, the phone star...   0   0
# 2     [['Chandler', 'Cookie?'], ['Monica', '(explain...   0   0
# 3     [['Chandler', 'And I just want a million dolla...   0   0
# 4     [['Monica', "Now I'm guessing that he bought h...   0   0
# ...                                                 ...  ..  ..
# 1143  [['Chandler', 'We have to bust it open, but ne...   1   0
# 1144  [['Monica', 'Alright. My job here is done.'], ...   1   0
# 1145  [['Monica', "Well, that's it. Everything's pac...   0   0
# 1146  [['Monica', "Oh, honey, I forgot. I promised T...   1   0
# 1147  [['Monica', '(crying) This is harder than I th...   1   1
#
# [1148 rows x 5 columns]

# %%
def adjust_sentiment(df):
    difference = df['C1'] - df['C2']
    if df['C1'] == df['C2']:
        val = df['C1']
    elif difference == -1 or difference == 1:
        val = 0
    else:
        if len(df['texts']) < 1100:
            val = 0
        else:
            val = 1
    return int(val)

# %%
gold_annotation_df = annotation_df
gold_annotation_df['gold_standard'] = annotation_df.apply(adjust_sentiment, axis=1)
gold_annotation_df = gold_annotation_df[["episode", "scene", "texts", "gold_standard"]]
gold_annotation_df
# Out:
#                                        episode  \
# 0     Episode 101: The Pilot-The Uncut Version
# 1     Episode 101: The Pilot-The Uncut Version
# 2     Episode 101: The Pilot-The Uncut Version
# 3     Episode 101: The Pilot-The Uncut Version
# 4     Episode 101: The Pilot-The Uncut Version
# ...                                        ...
# 1143            Episode 1018: The Last One (2)
# 1144            Episode 1018: The Last One (2)
# 1145            Episode 1018: The Last One (2)
# 1146            Episode 1018: The Last One (2)
# 1147            Episode 1018: The Last One (2)
#
#                                                   scene  \
# 0      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 1      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 2      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 3      Central Perk, Chandler, Joey, Phoebe, and Mon...
# 4      Central Perk, Chandler, Joey, Phoebe, and Mon...
# ...                                                 ...
# 1143   Joey's apartment. Joey and Chandler are still...
# 1144   Joey's apartment. Monica has completely destr...
# 1145   Monica and Chandler's apartment. Joey, Chandl...
# 1146   Monica and Chandler's apartment. Chandler and...
# 1147   Monica and Chandler's apartment. Chandler and...
#
#                                                   texts  gold_standard
# 0     [['Monica', "Okay, everybody relax. This is no...              0
# 1     [['Chandler', "All of a sudden, the phone star...              0
# 2     [['Chandler', 'Cookie?'], ['Monica', '(explain...              0
# 3     [['Chandler', 'And I just want a million dolla...              0
# 4     [['Monica', "Now I'm guessing that he bought h...              0
# ...                                                 ...            ...
# 1143  [['Chandler', 'We have to bust it open, but ne...              0
# 1144  [['Monica', 'Alright. My job here is done.'], ...              0
# 1145  [['Monica', "Well, that's it. Everything's pac...              0
# 1146  [['Monica', "Oh, honey, I forgot. I promised T...              0
# 1147  [['Monica', '(crying) This is harder than I th...              1
#
# [1148 rows x 4 columns]

# %%
gold_annotation_df['gold_standard'].sum()
# Out:
# 114

# %%
gold_annotation_df.to_csv("Monica_Chandler_Gold_Annotation.csv", index=False)

# %% [markdown]
# ## Generating graphs

# %%
overall_relationship_change = alt.Chart(gold_annotation_df).mark_line().encode(
    x=alt.X('episode', sort=None),
    y=alt.Y('sum(gold_standard)')).display(scaleFactor=2)
overall_relationship_change
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# overall_relationship_change.save('overall_relationship_change.json')

# %% [markdown]
# ### All Seasons

# %%
season1_episode_order = gold_annotation_df['episode'][:17].tolist()
season2_episode_order = gold_annotation_df['episode'][17:35].tolist()
season3_episode_order = gold_annotation_df['episode'][35:70].tolist()
season4_episode_order = gold_annotation_df['episode'][70:163].tolist()
season5_episode_order = gold_annotation_df['episode'][163:349].tolist()
season6_episode_order = gold_annotation_df['episode'][349:510].tolist()
season7_episode_order = gold_annotation_df['episode'][510:689].tolist()
season8_episode_order = gold_annotation_df['episode'][690:800].tolist()
season9_episode_order = gold_annotation_df['episode'][800:953].tolist()
season10_episode_order = gold_annotation_df['episode'][953:].tolist()

# %%
# episode_order
def season_sentiment(df, num):
    '''Input dataframe should only be gold_annotation_df, the number indicates the specific season.
       This function will return the graph of the relationship change in the specified season.'''
    if num > 0 and num < 11:
        if num == 1:
            season_episodes = df['episode'][:17].tolist()
            season = df[:17]
        elif num == 2:
            season_episodes = df['episode'][17:35].tolist()
            season = df[17:35]
        elif num == 3:
            season_episodes = df['episode'][35:70].tolist()
            season = df[35:70]
        elif num == 4:
            season_episodes = df['episode'][70:163].tolist()
            season = df[70:163]
        elif num == 5:
            season_episodes = df['episode'][163:349].tolist()
            season = df[163:349]
        elif num == 6:
            season_episodes = df['episode'][349:510].tolist()
            season = df[349:510]
        elif num == 7:
            season_episodes = df['episode'][510:689].tolist()
            season = df[510:689]
        elif num == 8:
            season_episodes = df['episode'][690:800].tolist()
            season = df[690:800]
        elif num == 9:
            season_episodes = df['episode'][800:953].tolist()
            season = df[800:953]
        else:
            season_episodes = df['episode'][953:].tolist()
            season = df[953:]
    
        graph = alt.Chart(season).mark_line().encode(
            x=alt.X('episode', sort=season_episodes),
            y=alt.Y('sum(gold_standard)')).display(scaleFactor=2)
    
    else:
        print("Season number out of range.")
    
    return graph

# %%
season1_graph = season_sentiment(gold_annotation_df, 1)
season2_graph = season_sentiment(gold_annotation_df, 2)
season3_graph = season_sentiment(gold_annotation_df, 3)
season4_graph = season_sentiment(gold_annotation_df, 4)
season5_graph = season_sentiment(gold_annotation_df, 5)
season6_graph = season_sentiment(gold_annotation_df, 6)
season7_graph = season_sentiment(gold_annotation_df, 7)
season8_graph = season_sentiment(gold_annotation_df, 8)
season9_graph = season_sentiment(gold_annotation_df, 9)
season10_graph = season_sentiment(gold_annotation_df, 10)
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### Season 1

# %%
season1_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season1_graph.save('season1_graph.json')

# %% [markdown]
# ### Season 2

# %%
season2_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season2_graph.save('season2_graph.png')
# season2_graph.save('season2_graph.png', engine="altair_saver")

# %% [markdown]
# ### Season 3

# %%
season3_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season3_graph.save('season3_graph.png')

# %% [markdown]
# ### Season 4

# %%
season4_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season4_graph.save('season4_graph.json')

# %% [markdown]
# ### Season 5

# %%
season5_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season5_graph.save('season5_graph.json')

# %% [markdown]
# ### Season 6

# %%
season6_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season6_graph.save('season6_graph.json')

# %% [markdown]
# ### Season 7

# %%
season7_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season7_graph.save('season7_graph.json')

# %% [markdown]
# ### Season 8

# %%
season8_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season8_graph.save('season8_graph.json')

# %% [markdown]
# ### Season 9

# %%
season9_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season9_graph.save('season9_graph.json')

# %% [markdown]
# ### Season 10

# %%
season10_graph
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# season10_graph.save('season10_graph.json')
